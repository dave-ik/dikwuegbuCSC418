# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/sst-foyer.jpg')

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# %%
inverse_image = 255 - image

# %%
cv2.imwrite('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/inverse_image.jpg', inverse_image)
# Out:
# True

# %%
plt.subplot(1, 2, 2)
plt.title("Inverse Color")
plt.imshow(inverse_image)
plt.show()
