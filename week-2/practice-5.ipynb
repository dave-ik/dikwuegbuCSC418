# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/sst-foyer.jpg')

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# %%
filtered_image = cv2.medianBlur(image, 15)

# %%
cv2.imwrite('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/Median-Blur.jpg', filtered_image)
# Out:
# True

# %%
plt.subplot(1, 2, 2)
plt.title("Median Blur")
plt.imshow(filtered_image)
plt.show()
