# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/sst.jpg')

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# %%
scaled_image = cv2.resize(image, None, fx=2, fy=2)

# %%
cv2.imwrite('C:/Users/2122/Desktop/dikwuegbuCSC418/dikwuegbuCSC418/week-2/Scaled.jpg', scaled_image)
# Out:
# True

# %%
plt.subplot(1, 2, 2)
plt.title("Scaled")
plt.imshow(scaled_image)
plt.show()
